# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#  Load the CSV file
df = pd.read_csv("Pakistan_Poverty_Dataset_2000_2023 (1).csv")

# %%
# Clean the data
df.dropna(inplace=True)

# %%
# Rename columns for easier access
df.rename(columns={
    'Unemployment Rate (%)': 'Unemployment',
    'Year': 'Year'
}, inplace=True)

# %%
# Plot: Unemployment Rate Over Time
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Unemployment', marker='o', color='blue')
plt.title('📈 Unemployment Rate in Pakistan (2000–2023)', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5572\3069794652.py:8: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\hp\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# COVID-19 Period: 2019–2021
covid_years = df[df['Year'].between(2019, 2021)]

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=covid_years, x='Year', y='Unemployment', palette='Reds')
plt.title('🦠 Unemployment Spike During COVID-19 (2019–2021)', fontsize=13)
plt.xlabel('Year')
plt.ylabel('Unemployment Rate (%)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5572\4154404880.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=covid_years, x='Year', y='Unemployment', palette='Reds')
# C:\Users\hp\AppData\Local\Temp\ipykernel_5572\4154404880.py:6: UserWarning: Glyph 129440 (\N{MICROBE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\hp\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 129440 (\N{MICROBE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Correlation Heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('📊 Correlation Between Economic Indicators', fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5572\2034789781.py:5: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\hp\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
